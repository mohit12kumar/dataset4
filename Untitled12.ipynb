# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit12kumar/dataset4/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
filepath = r'https://media.githubusercontent.com/media/mohit12kumar/dataset4/refs/heads/main/flights_sample_3m.csv?token=BXTF7Y7L33P5DXTBBBJD7UTJ2N7QS'
data = pd.read_csv(filepath)
data.head()
# Out:
#       FL_DATE                AIRLINE                AIRLINE_DOT AIRLINE_CODE  \
# 0  2019-01-09  United Air Lines Inc.  United Air Lines Inc.: UA           UA
# 1  2022-11-19   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL
# 2  2022-07-22  United Air Lines Inc.  United Air Lines Inc.: UA           UA
# 3  2023-03-06   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL
# 4  2020-02-23       Spirit Air Lines       Spirit Air Lines: NK           NK
#
#    DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY DEST  \
# 0     19977       1562    FLL  Fort Lauderdale, FL  EWR
# 1     19790       1149    MSP      Minneapolis, MN  SEA
# 2     19977        459    DEN           Denver, CO  MSP
# 3     19790       2295    MSP      Minneapolis, MN  SFO
# 4     20416        407    MCO          Orlando, FL  DFW
#
#                DEST_CITY  ...  DIVERTED  CRS_ELAPSED_TIME  ELAPSED_TIME  \
# 0             Newark, NJ  ...       0.0             186.0         176.0
# 1            Seattle, WA  ...       0.0             235.0         236.0
# 2        Minneapolis, MN  ...       0.0             118.0         112.0
# 3      San Francisco, CA  ...       0.0             260.0         285.0
# 4  Dallas/Fort Worth, TX  ...       0.0             181.0         182.0
#
#    AIR_TIME  DISTANCE  DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  DELAY_DUE_NAS  \
# 0     153.0    1065.0                NaN                NaN            NaN
# 1     189.0    1399.0                NaN                NaN            NaN
# 2      87.0     680.0                NaN                NaN            NaN
# 3     249.0    1589.0                0.0                0.0           24.0
# 4     153.0     985.0                NaN                NaN            NaN
#
#    DELAY_DUE_SECURITY  DELAY_DUE_LATE_AIRCRAFT
# 0                 NaN                      NaN
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 0.0                      0.0
# 4                 NaN                      NaN
#
# [5 rows x 32 columns]

# %%
data.isnull().sum()
# Out:
# FL_DATE                          0
# AIRLINE                          0
# AIRLINE_DOT                      0
# AIRLINE_CODE                     0
# DOT_CODE                         0
# FL_NUMBER                        0
# ORIGIN                           0
# ORIGIN_CITY                      0
# DEST                             0
# DEST_CITY                        0
# CRS_DEP_TIME                     0
# DEP_TIME                     77615
# DEP_DELAY                    77644
# TAXI_OUT                     78806
# WHEELS_OFF                   78806
# WHEELS_ON                    79944
# TAXI_IN                      79944
# CRS_ARR_TIME                     0
# ARR_TIME                     79942
# ARR_DELAY                    86198
# CANCELLED                        0
# CANCELLATION_CODE          2920860
# DIVERTED                         0
# CRS_ELAPSED_TIME                14
# ELAPSED_TIME                 86198
# AIR_TIME                     86198
# DISTANCE                         0
# DELAY_DUE_CARRIER          2466137
# DELAY_DUE_WEATHER          2466137
# DELAY_DUE_NAS              2466137
# DELAY_DUE_SECURITY         2466137
# DELAY_DUE_LATE_AIRCRAFT    2466137
# dtype: int64

# %%
data.describe()
# Out:
#            DOT_CODE     FL_NUMBER  CRS_DEP_TIME      DEP_TIME     DEP_DELAY  \
# count  3.000000e+06  3.000000e+06  3.000000e+06  2.922385e+06  2.922356e+06
# mean   1.997629e+04  2.511536e+03  1.327062e+03  1.329776e+03  1.012333e+01
# std    3.772846e+02  1.747258e+03  4.858789e+02  4.993101e+02  4.925183e+01
# min    1.939300e+04  1.000000e+00  1.000000e+00  1.000000e+00 -9.000000e+01
# 25%    1.979000e+04  1.051000e+03  9.150000e+02  9.160000e+02 -6.000000e+00
# 50%    1.993000e+04  2.152000e+03  1.320000e+03  1.323000e+03 -2.000000e+00
# 75%    2.036800e+04  3.797000e+03  1.730000e+03  1.739000e+03  6.000000e+00
# max    2.045200e+04  9.562000e+03  2.359000e+03  2.400000e+03  2.966000e+03
#
#            TAXI_OUT    WHEELS_OFF     WHEELS_ON       TAXI_IN  CRS_ARR_TIME  \
# count  2.921194e+06  2.921194e+06  2.920056e+06  2.920056e+06  3.000000e+06
# mean   1.664305e+01  1.352361e+03  1.462500e+03  7.678982e+00  1.490561e+03
# std    9.192901e+00  5.008727e+02  5.272368e+02  6.269639e+00  5.115476e+02
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.100000e+01  9.310000e+02  1.049000e+03  4.000000e+00  1.107000e+03
# 50%    1.400000e+01  1.336000e+03  1.501000e+03  6.000000e+00  1.516000e+03
# 75%    1.900000e+01  1.752000e+03  1.908000e+03  9.000000e+00  1.919000e+03
# max    1.840000e+02  2.400000e+03  2.400000e+03  2.490000e+02  2.400000e+03
#
#        ...      DIVERTED  CRS_ELAPSED_TIME  ELAPSED_TIME      AIR_TIME  \
# count  ...  3.000000e+06      2.999986e+06  2.913802e+06  2.913802e+06
# mean   ...  2.352000e-03      1.422758e+02  1.366205e+02  1.123108e+02
# std    ...  4.844036e-02      7.155669e+01  7.167582e+01  6.975484e+01
# min    ...  0.000000e+00      1.000000e+00  1.500000e+01  8.000000e+00
# 25%    ...  0.000000e+00      9.000000e+01  8.400000e+01  6.100000e+01
# 50%    ...  0.000000e+00      1.250000e+02  1.200000e+02  9.500000e+01
# 75%    ...  0.000000e+00      1.720000e+02  1.670000e+02  1.420000e+02
# max    ...  1.000000e+00      7.050000e+02  7.390000e+02  6.920000e+02
#
#            DISTANCE  DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  DELAY_DUE_NAS  \
# count  3.000000e+06      533863.000000      533863.000000  533863.000000
# mean   8.093616e+02          24.759086           3.985260      13.164728
# std    5.878939e+02          71.771845          32.410796      33.161122
# min    2.900000e+01           0.000000           0.000000       0.000000
# 25%    3.770000e+02           0.000000           0.000000       0.000000
# 50%    6.510000e+02           4.000000           0.000000       0.000000
# 75%    1.046000e+03          23.000000           0.000000      17.000000
# max    5.812000e+03        2934.000000        1653.000000    1741.000000
#
#        DELAY_DUE_SECURITY  DELAY_DUE_LATE_AIRCRAFT
# count       533863.000000            533863.000000
# mean             0.145931                25.471282
# std              3.582053                55.766892
# min              0.000000                 0.000000
# 25%              0.000000                 0.000000
# 50%              0.000000                 0.000000
# 75%              0.000000                30.000000
# max           1185.000000              2557.000000
#
# [8 rows x 23 columns]

# %%
l1 = LabelEncoder()
for col in data.columns:
  if data[col].dtype=="object":
    data[col]=l1.fit_transform(data[col])
data.head()
# Out:
#    FL_DATE  AIRLINE  AIRLINE_DOT  AIRLINE_CODE  DOT_CODE  FL_NUMBER  ORIGIN  \
# 0        8       17           17            14     19977       1562     131
# 1     1418        3            3             4     19790       1149     247
# 2     1298       17           17            14     19977        459      99
# 3     1525        3            3             4     19790       2295     247
# 4      418       16           16            10     20416        407     223
#
#    ORIGIN_CITY  DEST  DEST_CITY  ...  DIVERTED  CRS_ELAPSED_TIME  \
# 0          118   123        240  ...       0.0             186.0
# 1          220   323        318  ...       0.0             235.0
# 2           89   247        220  ...       0.0             118.0
# 3          220   325        303  ...       0.0             260.0
# 4          254   100         83  ...       0.0             181.0
#
#    ELAPSED_TIME  AIR_TIME  DISTANCE  DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  \
# 0         176.0     153.0    1065.0                NaN                NaN
# 1         236.0     189.0    1399.0                NaN                NaN
# 2         112.0      87.0     680.0                NaN                NaN
# 3         285.0     249.0    1589.0                0.0                0.0
# 4         182.0     153.0     985.0                NaN                NaN
#
#    DELAY_DUE_NAS  DELAY_DUE_SECURITY  DELAY_DUE_LATE_AIRCRAFT
# 0            NaN                 NaN                      NaN
# 1            NaN                 NaN                      NaN
# 2            NaN                 NaN                      NaN
# 3           24.0                 0.0                      0.0
# 4            NaN                 NaN                      NaN
#
# [5 rows x 32 columns]

# %%
data.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2999995    False
# 2999996    False
# 2999997    False
# 2999998    False
# 2999999    False
# Length: 3000000, dtype: bool

# %%
data.drop([
    'CANCELLATION_CODE',
    'DELAY_DUE_CARRIER',
    'DELAY_DUE_WEATHER',
    'DELAY_DUE_NAS',
    'DELAY_DUE_SECURITY',
    'DELAY_DUE_LATE_AIRCRAFT',
    'FL_NUMBER',
    'AIRLINE_DOT',
    'DOT_CODE',
    'TAXI_OUT',
    'WHEELS_OFF',
    'WHEELS_ON',
    'TAXI_IN'
], axis=1, inplace=True)

# %%
data['ELAPSED_TIME'].fillna(data['CRS_ELAPSED_TIME'], inplace=True)
data['AIR_TIME'].fillna(data['ELAPSED_TIME'], inplace=True)
# Out:
# /tmp/ipykernel_3976/494364945.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['ELAPSED_TIME'].fillna(data['CRS_ELAPSED_TIME'], inplace=True)
# /tmp/ipykernel_3976/494364945.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['AIR_TIME'].fillna(data['ELAPSED_TIME'], inplace=True)

# %%
data['CRS_ELAPSED_TIME'].fillna(data['CRS_ELAPSED_TIME'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_3976/2574872280.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['CRS_ELAPSED_TIME'].fillna(data['CRS_ELAPSED_TIME'].mean(), inplace=True)

# %%
# For cancelled flights, delays are missing → fill with 0
data['ARR_DELAY'].fillna(0, inplace=True)
data['DEP_DELAY'].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_3976/3322146999.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['ARR_DELAY'].fillna(0, inplace=True)
# /tmp/ipykernel_3976/3322146999.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['DEP_DELAY'].fillna(0, inplace=True)

# %%
data['DEP_TIME'].fillna(data['CRS_DEP_TIME'], inplace=True)
data['ARR_TIME'].fillna(data['CRS_ARR_TIME'], inplace=True)
# Out:
# /tmp/ipykernel_3976/4003532243.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['DEP_TIME'].fillna(data['CRS_DEP_TIME'], inplace=True)
# /tmp/ipykernel_3976/4003532243.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['ARR_TIME'].fillna(data['CRS_ARR_TIME'], inplace=True)

# %%
data['ELAPSED_TIME'].fillna(data['ELAPSED_TIME'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_3976/1788679656.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['ELAPSED_TIME'].fillna(data['ELAPSED_TIME'].mean(), inplace=True)

# %%
data['AIR_TIME'].fillna(data['AIR_TIME'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_3976/2803003562.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['AIR_TIME'].fillna(data['AIR_TIME'].mean(), inplace=True)

# %%
data['FL_DATE'] = pd.to_datetime(data['FL_DATE'])

data['month'] = data['FL_DATE'].dt.month
data['day'] = data['FL_DATE'].dt.day
data['day_of_week'] = data['FL_DATE'].dt.dayofweek

# Weekend feature
data['is_weekend'] = data['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)

# %%
data.isnull().sum()
# Out:
# FL_DATE             0
# AIRLINE             0
# AIRLINE_CODE        0
# ORIGIN              0
# ORIGIN_CITY         0
# DEST                0
# DEST_CITY           0
# CRS_DEP_TIME        0
# DEP_TIME            0
# DEP_DELAY           0
# CRS_ARR_TIME        0
# ARR_TIME            0
# ARR_DELAY           0
# CANCELLED           0
# DIVERTED            0
# CRS_ELAPSED_TIME    0
# ELAPSED_TIME        0
# AIR_TIME            0
# DISTANCE            0
# month               0
# day                 0
# day_of_week         0
# is_weekend          0
# dtype: int64

# %%
import seaborn as sns
corr = data.corr()
plt.figure(figsize=(25,25))
sns.heatmap(corr, annot=True)
plt.show()

# %%
data.corr()
# Out:
#                    FL_DATE   AIRLINE  AIRLINE_CODE    ORIGIN  ORIGIN_CITY  \
# FL_DATE           1.000000  0.011422     -0.001405  0.002251     0.014767
# AIRLINE           0.011422  1.000000      0.884530  0.040754     0.037923
# AIRLINE_CODE     -0.001405  0.884530      1.000000  0.047987     0.043697
# ORIGIN            0.002251  0.040754      0.047987  1.000000     0.742938
# ORIGIN_CITY       0.014767  0.037923      0.043697  0.742938     1.000000
# DEST              0.001992  0.040486      0.047062  0.007171     0.002535
# DEST_CITY         0.013941  0.037831      0.043431  0.003074    -0.011847
# CRS_DEP_TIME      0.004788  0.003403     -0.000660 -0.035605    -0.043316
# DEP_TIME          0.005750  0.005917      0.003970 -0.036067    -0.043962
# DEP_DELAY         0.040806  0.009054     -0.005355 -0.008148    -0.006653
# CRS_ARR_TIME     -0.001849 -0.011353     -0.004100 -0.010122    -0.019966
# ARR_TIME         -0.009200 -0.009131      0.000543 -0.006263    -0.018043
# ARR_DELAY         0.043272  0.002200     -0.007633 -0.007752    -0.008181
# CANCELLED        -0.028620  0.012019      0.018023 -0.003692    -0.001795
# DIVERTED          0.001556  0.000520     -0.000606  0.002113     0.000301
# CRS_ELAPSED_TIME  0.019439 -0.110596     -0.171936  0.068111     0.084581
# ELAPSED_TIME      0.022363 -0.115418     -0.173974  0.068260     0.083437
# AIR_TIME          0.017516 -0.102363     -0.158360  0.069673     0.082623
# DISTANCE          0.023068 -0.103661     -0.160665  0.087271     0.087624
# month                  NaN       NaN           NaN       NaN          NaN
# day                    NaN       NaN           NaN       NaN          NaN
# day_of_week            NaN       NaN           NaN       NaN          NaN
# is_weekend             NaN       NaN           NaN       NaN          NaN
#
#                       DEST  DEST_CITY  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  ...  \
# FL_DATE           0.001992   0.013941      0.004788  0.005750   0.040806  ...
# AIRLINE           0.040486   0.037831      0.003403  0.005917   0.009054  ...
# AIRLINE_CODE      0.047062   0.043431     -0.000660  0.003970  -0.005355  ...
# ORIGIN            0.007171   0.003074     -0.035605 -0.036067  -0.008148  ...
# ORIGIN_CITY       0.002535  -0.011847     -0.043316 -0.043962  -0.006653  ...
# DEST              1.000000   0.742928      0.029705  0.029622  -0.000388  ...
# DEST_CITY         0.742928   1.000000      0.045850  0.045032   0.001311  ...
# CRS_DEP_TIME      0.029705   0.045850      1.000000  0.955860   0.091180  ...
# DEP_TIME          0.029622   0.045032      0.955860  1.000000   0.117715  ...
# DEP_DELAY        -0.000388   0.001311      0.091180  0.117715   1.000000  ...
# CRS_ARR_TIME      0.021393   0.042136      0.701677  0.704904   0.071697  ...
# ARR_TIME          0.018642   0.035173      0.613373  0.636986   0.013725  ...
# ARR_DELAY        -0.000918   0.002834      0.088322  0.115722   0.959140  ...
# CANCELLED        -0.004379  -0.003264      0.011832  0.010619  -0.029280  ...
# DIVERTED         -0.003705  -0.001605      0.001419  0.002557   0.019046  ...
# CRS_ELAPSED_TIME  0.095841   0.083295     -0.017868 -0.023039   0.024617  ...
# ELAPSED_TIME      0.095459   0.084566     -0.017190 -0.020996   0.028801  ...
# AIR_TIME          0.102621   0.094122     -0.014146 -0.019446   0.019796  ...
# DISTANCE          0.087132   0.087687     -0.008490 -0.016121   0.022475  ...
# month                  NaN        NaN           NaN       NaN        NaN  ...
# day                    NaN        NaN           NaN       NaN        NaN  ...
# day_of_week            NaN        NaN           NaN       NaN        NaN  ...
# is_weekend             NaN        NaN           NaN       NaN        NaN  ...
#
#                   CANCELLED  DIVERTED  CRS_ELAPSED_TIME  ELAPSED_TIME  \
# FL_DATE           -0.028620  0.001556          0.019439      0.022363
# AIRLINE            0.012019  0.000520         -0.110596     -0.115418
# AIRLINE_CODE       0.018023 -0.000606         -0.171936     -0.173974
# ORIGIN            -0.003692  0.002113          0.068111      0.068260
# ORIGIN_CITY       -0.001795  0.000301          0.084581      0.083437
# DEST              -0.004379 -0.003705          0.095841      0.095459
# DEST_CITY         -0.003264 -0.001605          0.083295      0.084566
# CRS_DEP_TIME       0.011832  0.001419         -0.017868     -0.017190
# DEP_TIME           0.010619  0.002557         -0.023039     -0.020996
# DEP_DELAY         -0.029280  0.019046          0.024617      0.028801
# CRS_ARR_TIME       0.006653  0.006954          0.021669      0.023642
# ARR_TIME           0.013464  0.006256          0.011275      0.015710
# ARR_DELAY         -0.013505 -0.003984         -0.002222      0.050671
# CANCELLED          1.000000 -0.007992         -0.015435     -0.002504
# DIVERTED          -0.007992  1.000000          0.013535      0.017362
# CRS_ELAPSED_TIME  -0.015435  0.013535          1.000000      0.982707
# ELAPSED_TIME      -0.002504  0.017362          0.982707      1.000000
# AIR_TIME           0.053131  0.034227          0.986879      0.986361
# DISTANCE          -0.017814  0.012618          0.982453      0.969594
# month                   NaN       NaN               NaN           NaN
# day                     NaN       NaN               NaN           NaN
# day_of_week             NaN       NaN               NaN           NaN
# is_weekend              NaN       NaN               NaN           NaN
#
#                   AIR_TIME  DISTANCE  month  day  day_of_week  is_weekend
# FL_DATE           0.017516  0.023068    NaN  NaN          NaN         NaN
# AIRLINE          -0.102363 -0.103661    NaN  NaN          NaN         NaN
# AIRLINE_CODE     -0.158360 -0.160665    NaN  NaN          NaN         NaN
# ORIGIN            0.069673  0.087271    NaN  NaN          NaN         NaN
# ORIGIN_CITY       0.082623  0.087624    NaN  NaN          NaN         NaN
# DEST              0.102621  0.087132    NaN  NaN          NaN         NaN
# DEST_CITY         0.094122  0.087687    NaN  NaN          NaN         NaN
# CRS_DEP_TIME     -0.014146 -0.008490    NaN  NaN          NaN         NaN
# DEP_TIME         -0.019446 -0.016121    NaN  NaN          NaN         NaN
# DEP_DELAY         0.019796  0.022475    NaN  NaN          NaN         NaN
# CRS_ARR_TIME      0.022845  0.020508    NaN  NaN          NaN         NaN
# ARR_TIME          0.014585  0.009700    NaN  NaN          NaN         NaN
# ARR_DELAY         0.016044  0.002051    NaN  NaN          NaN         NaN
# CANCELLED         0.053131 -0.017814    NaN  NaN          NaN         NaN
# DIVERTED          0.034227  0.012618    NaN  NaN          NaN         NaN
# CRS_ELAPSED_TIME  0.986879  0.982453    NaN  NaN          NaN         NaN
# ELAPSED_TIME      0.986361  0.969594    NaN  NaN          NaN         NaN
# AIR_TIME          1.000000  0.980980    NaN  NaN          NaN         NaN
# DISTANCE          0.980980  1.000000    NaN  NaN          NaN         NaN
# month                  NaN       NaN    NaN  NaN          NaN         NaN
# day                    NaN       NaN    NaN  NaN          NaN         NaN
# day_of_week            NaN       NaN    NaN  NaN          NaN         NaN
# is_weekend             NaN       NaN    NaN  NaN          NaN         NaN
#
# [23 rows x 23 columns]

# %%
drop_cols = [
    'AIRLINE_CODE',        # Duplicate info
    'ORIGIN_CITY',         # Same as ORIGIN
    'DEST_CITY',           # Same as DEST
    'ARR_TIME',            # Data leakage
    'ARR_DELAY',           # Data leakage
    'ELAPSED_TIME',
    'AIR_TIME',
    'CRS_ELAPSED_TIME'
]

# %%
data[[
    'AIRLINE',
    'ORIGIN',
    'DEST',
    'DEP_DELAY',
    'DISTANCE',
    'CRS_DEP_TIME',
    'month',
    'day_of_week',
    'is_weekend',
    'ARR_DELAY',
    'CANCELLED'

]].to_csv(r"C:\Users\riyam\Downloads\archive (11)\dataset4\project14.csv", index=False)

# %%
print(os.getcwd())
print(os.path.exists(r"C:\Users\riyam\Downloads\archive (11)\dataset4\project14.csv"))
# Out:
# /content
# True

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import gc
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
filepath = r'https://media.githubusercontent.com/media/mohit12kumar/dataset4/refs/heads/main/project14.csv'
data = pd.read_csv(filepath)
data.head()
# Out:
#    AIRLINE  ORIGIN  DEST  DEP_DELAY  DISTANCE  CRS_DEP_TIME  month  \
# 0       17     131   123       -4.0    1065.0          1155      1
# 1        3     247   323       -6.0    1399.0          2120      1
# 2       17      99   247        6.0     680.0           954      1
# 3        3     247   325       -1.0    1589.0          1609      1
# 4       16     223   100       -2.0     985.0          1840      1
#
#    day_of_week  is_weekend  ARR_DELAY  CANCELLED
# 0            3           0      -14.0        0.0
# 1            3           0       -5.0        0.0
# 2            3           0        0.0        0.0
# 3            3           0       24.0        0.0
# 4            3           0       -1.0        0.0

# %%
x= data[[
    'AIRLINE',
    'ORIGIN',
    'DEST',
    'DEP_DELAY',
    'DISTANCE',
    'CRS_DEP_TIME',
    'month',
    'day_of_week',
    'is_weekend'
]]
y = (data["ARR_DELAY"] > 15).astype(int)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 42 )
# sm = SMOTE(random_state=42)
# x_train, y_train = sm.fit_resample(x_train, y_train)

# %%
rf = RandomForestClassifier(
    n_estimators=200,        # 🔥 reduced (400 → 150)
    max_depth=15,            # 🔥 limit depth
    min_samples_split=10,
    min_samples_leaf=5,
    class_weight='balanced',
    n_jobs=2,                # 🔥 LIMIT CPU (important)
    random_state=42
)
rf.fit(x_train, y_train)
rf_pred = rf.predict(x_test)
print(rf_pred,y_test)
print("\n test accuracy = ",accuracy_score(y_test,rf_pred))
print("Report:\n", classification_report(y_test, rf_pred))
from functools import cmp_to_key
c1 = confusion_matrix(y_test,rf_pred)
print("confusion matrix:\n",c1)
unique_labels = sorted(list(set(y_test).union(set(rf_pred))))
cm_display = ConfusionMatrixDisplay(confusion_matrix=c1,display_labels=unique_labels)
cm_display.plot(cmap = "Blues",xticks_rotation = 45)
plt.show()
import gc
gc.collect()
# Out:
# [0 0 0 ... 0 1 0] 2945667    0
# 2352586    0
# 1531260    0
# 941910     0
# 2582125    1
#           ..
# 1945004    0
# 2425256    0
# 1592737    0
# 601096     0
# 2635925    0
# Name: ARR_DELAY, Length: 600000, dtype: int64
#
#  test accuracy =  0.9190383333333333
# Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95    496574
#            1       0.74      0.81      0.78    103426
#
#     accuracy                           0.92    600000
#    macro avg       0.85      0.88      0.86    600000
# weighted avg       0.92      0.92      0.92    600000
#
# confusion matrix:
#  [[467387  29187]
#  [ 19390  84036]]
# 13141

# %%
lr=LogisticRegression(class_weight='balanced',
    max_iter=500,
    n_jobs=-1)
lr.fit(x_train, y_train)
lr_pred = lr.predict(x_test)
print(lr_pred,y_test)
print("\n test accuracy = ",accuracy_score(y_test,lr_pred))
print("Report:\n", classification_report(y_test, lr_pred))
c2 = confusion_matrix(y_test,lr_pred)
print("confusion matrix:\n",c2)
unique_labels = sorted(list(set(y_test).union(set(lr_pred))))
cm_display = ConfusionMatrixDisplay(confusion_matrix=c2,display_labels=unique_labels)
cm_display.plot(cmap = "Blues",xticks_rotation = 45)
plt.show()
import gc
gc.collect()
# Out:
# [0 0 0 ... 0 1 0] 2945667    0
# 2352586    0
# 1531260    0
# 941910     0
# 2582125    1
#           ..
# 1945004    0
# 2425256    0
# 1592737    0
# 601096     0
# 2635925    0
# Name: ARR_DELAY, Length: 600000, dtype: int64
#
#  test accuracy =  0.9105383333333333
# Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95    496574
#            1       0.71      0.82      0.76    103426
#
#     accuracy                           0.91    600000
#    macro avg       0.83      0.88      0.85    600000
# weighted avg       0.92      0.91      0.91    600000
#
# confusion matrix:
#  [[461245  35329]
#  [ 18348  85078]]
# 4921

# %%
dt = DecisionTreeClassifier(
    max_depth=10,              # 🔥 prevent overfitting
    min_samples_split=20,
    min_samples_leaf=10,
    class_weight='balanced',
    random_state=42
)
dt.fit(x_train, y_train)
dt_pred = dt.predict(x_test)
print(dt_pred,y_test)
print("\n test accuracy = ",accuracy_score(y_test,dt_pred))
print("Report:\n", classification_report(y_test, dt_pred))
from functools import cmp_to_key
c3 = confusion_matrix(y_test,dt_pred)
print("confusion matrix:\n",c3)
unique_labels = sorted(list(set(y_test).union(set(dt_pred))))
cm_display = ConfusionMatrixDisplay(confusion_matrix=c3,display_labels=unique_labels)
cm_display.plot(cmap = "Blues",xticks_rotation = 45)
plt.show()
import gc
gc.collect()
# Out:
# [0 0 0 ... 0 1 0] 2945667    0
# 2352586    0
# 1531260    0
# 941910     0
# 2582125    1
#           ..
# 1945004    0
# 2425256    0
# 1592737    0
# 601096     0
# 2635925    0
# Name: ARR_DELAY, Length: 600000, dtype: int64
#
#  test accuracy =  0.9128716666666666
# Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95    496574
#            1       0.72      0.82      0.76    103426
#
#     accuracy                           0.91    600000
#    macro avg       0.84      0.88      0.86    600000
# weighted avg       0.92      0.91      0.92    600000
#
# confusion matrix:
#  [[462770  33804]
#  [ 18473  84953]]
# 4681

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
knn_pred = knn.predict(x_test)
print(knn_pred,y_test)
print("\n test accuracy = ",accuracy_score(y_test,knn_pred))
print("Report:\n", classification_report(y_test, knn_pred))
c4 = confusion_matrix(y_test,knn_pred)
print("confusion matrix:\n",c4)
unique_labels = sorted(list(set(y_test).union(set(knn_pred))))
cm_display = ConfusionMatrixDisplay(confusion_matrix=c4,display_labels=unique_labels)
cm_display.plot(cmap = "Blues",xticks_rotation = 45)
plt.show()
import gc
gc.collect()
# Out:
# [0 0 0 ... 0 0 0] 2945667    0
# 2352586    0
# 1531260    0
# 941910     0
# 2582125    1
#           ..
# 1945004    0
# 2425256    0
# 1592737    0
# 601096     0
# 2635925    0
# Name: ARR_DELAY, Length: 600000, dtype: int64
#
#  test accuracy =  0.92717
# Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96    496574
#            1       0.90      0.65      0.75    103426
#
#     accuracy                           0.93    600000
#    macro avg       0.92      0.82      0.86    600000
# weighted avg       0.93      0.93      0.92    600000
#
# confusion matrix:
#  [[489062   7512]
#  [ 36186  67240]]
# 4672

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.svm import LinearSVC
svm = LinearSVC(                    # 🔥 model changed
    class_weight='balanced',
    max_iter=3000,
    dual=False,
    random_state=42
)
svm.fit(x_train, y_train)
svm_pred = svm.predict(x_test)
print(svm_pred,y_test)
print("\n test accuracy = ",accuracy_score(y_test,svm_pred))
print("Report:\n", classification_report(y_test, svm_pred))
from functools import cmp_to_key
c5 = confusion_matrix(y_test,svm_pred)
print("confusion matrix:\n",c5)
unique_labels = sorted(list(set(y_test).union(set(svm_pred))))
cm_display = ConfusionMatrixDisplay(confusion_matrix=c5,display_labels=unique_labels)
cm_display.plot(cmap = "Blues",xticks_rotation = 45)
plt.show()
import gc
gc.collect()
# Out:
# [0 0 0 ... 0 0 0] 2945667    0
# 2352586    0
# 1531260    0
# 941910     0
# 2582125    1
#           ..
# 1945004    0
# 2425256    0
# 1592737    0
# 601096     0
# 2635925    0
# Name: ARR_DELAY, Length: 600000, dtype: int64
#
#  test accuracy =  0.918935
# Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95    496574
#            1       0.74      0.81      0.77    103426
#
#     accuracy                           0.92    600000
#    macro avg       0.85      0.88      0.86    600000
# weighted avg       0.92      0.92      0.92    600000
#
# confusion matrix:
#  [[467632  28942]
#  [ 19697  83729]]
# 4154

# %%
# scaler = StandardScaler()
# x = scaler.fit_transform(x)
scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()


model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=scale_pos_weight,   # 🔥 VERY IMPORTANT
    random_state=42,
    eval_metric='logloss'
)
model.fit(x_train, y_train)
y_prob = model.predict_proba(x_test)[:,1]

# 🔥 THRESHOLD TUNING
xg_pred = (y_prob > 0.4).astype(int)
print(xg_pred,y_test)
print("\n test accuracy = ",accuracy_score(y_test,xg_pred))
print("Report:\n", classification_report(y_test, xg_pred))
c6 = confusion_matrix(y_test,xg_pred)
print("confusion matrix:\n",c6)
unique_labels = sorted(list(set(y_test).union(set(xg_pred))))
cm_display = ConfusionMatrixDisplay(confusion_matrix=c6,display_labels=unique_labels)
cm_display.plot(cmap = "Blues",xticks_rotation = 45)
plt.show()
import gc
gc.collect()
# Out:
# [1 0 0 ... 0 1 0] 2945667    0
# 2352586    0
# 1531260    0
# 941910     0
# 2582125    1
#           ..
# 1945004    0
# 2425256    0
# 1592737    0
# 601096     0
# 2635925    0
# Name: ARR_DELAY, Length: 600000, dtype: int64
#
#  test accuracy =  0.8945183333333333
# Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93    496574
#            1       0.65      0.85      0.73    103426
#
#     accuracy                           0.89    600000
#    macro avg       0.81      0.88      0.83    600000
# weighted avg       0.91      0.89      0.90    600000
#
# confusion matrix:
#  [[449110  47464]
#  [ 15825  87601]]
# 4693

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(Dense(64, activation='relu', input_dim=x_train.shape[1]))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,265 (12.75 KB)
#  Trainable params: 3,265 (12.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# classes = np.unique(y_train)
# weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)

# class_weights = {0: weights[0], 1: weights[1]}

# print(class_weights)
# Out:
# {0: np.float64(0.6035801355741581), 1: np.float64(2.913590198682572)}

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(
    x_train, y_train,
    epochs=50,
    batch_size=256,
    validation_data=(x_test, y_test),
    callbacks=[early_stop]
    # class_weight=class_weights
)
dt_pred = model.predict(x_test)
dt_pred = (y_pred > 0.35).astype(int)
print(dt_pred,y_test)
# Out:
# Epoch 1/50
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.9379 - loss: 0.1904 - val_accuracy: 0.9376 - val_loss: 0.1928
# Epoch 2/50
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.9381 - loss: 0.1902 - val_accuracy: 0.9376 - val_loss: 0.1933
# Epoch 3/50
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.9380 - loss: 0.1901 - val_accuracy: 0.9376 - val_loss: 0.1954
# Epoch 4/50
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 21s 2ms/step - accuracy: 0.9380 - loss: 0.1902 - val_accuracy: 0.9377 - val_loss: 0.1938
# 18750/18750 ━━━━━━━━━━━━━━━━━━━━ 16s 843us/step
# [1 0 0 ... 0 1 0] 2945667    0
# 2352586    0
# 1531260    0
# 941910     0
# 2582125    1
#           ..
# 1945004    0
# 2425256    0
# 1592737    0
# 601096     0
# 2635925    0
# Name: ARR_DELAY, Length: 600000, dtype: int64

# %%
print(y_train.value_counts())
# Out:
# ARR_DELAY
# 0    1988137
# 1     411863
# Name: count, dtype: int64

# %%
print("\n test accuracy = ",accuracy_score(y_test,dt_pred))
# Out:
#  test accuracy =  0.8945183333333333

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])

plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])

plt.show()

# %%
print("Report:\n", classification_report(y_test, dt_pred))
# Out:
# Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93    496574
#            1       0.65      0.85      0.73    103426
#
#     accuracy                           0.89    600000
#    macro avg       0.81      0.88      0.83    600000
# weighted avg       0.91      0.89      0.90    600000

# %%
c7 = confusion_matrix(y_test,dt_pred)
print("confusion matrix:\n",c7)
cm_display = ConfusionMatrixDisplay(confusion_matrix=c7,display_labels=["On Time", "Delayed"])
cm_display.plot(cmap = "Blues",xticks_rotation = 45)
plt.show()
# gc.collect()
# Out:
# confusion matrix:
#  [[449110  47464]
#  [ 15825  87601]]

# %%
results = []

def evaluate_model(name, y_true, y_pred):
    from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1": f1_score(y_true, y_pred)
    })
evaluate_model("Random Forest", y_test, rf_pred)
evaluate_model("XGBoost", y_test, xg_pred)
evaluate_model("Deep Learning", y_test, dt_pred)
evaluate_model("KNN", y_test, knn_pred)
evaluate_model("Logistic Regression", y_test, lr_pred)
evaluate_model("decision tree", y_test, dt_pred)
evaluate_model("svm", y_test, svm_pred)

# %%
df = pd.DataFrame(results)
print(df.sort_values(by="F1", ascending=False))
# Out:
#                  Model  Accuracy  Precision    Recall        F1
# 0        Random Forest  0.919038   0.742217  0.812523  0.775780
# 6                  svm  0.918935   0.743128  0.809555  0.774921
# 4  Logistic Regression  0.910538   0.706587  0.822598  0.760192
# 3                  KNN  0.927170   0.899508  0.650127  0.754751
# 1              XGBoost  0.894518   0.648584  0.846992  0.734627
# 2        Deep Learning  0.894518   0.648584  0.846992  0.734627
# 5        decision tree  0.894518   0.648584  0.846992  0.734627
